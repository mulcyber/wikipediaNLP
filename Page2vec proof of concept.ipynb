# %%
import pickle

abstract_keyedvec_path = path.join(DATA_folder, "precomp", "abs_keyed_vec.pkl")
absKeyedVec = pickle.load(open(abstract_keyedvec_path, "rb"))


# Example from https://radimrehurek.com/gensim/models/keyedvectors.html#gensim.models.keyedvectors.KeyedVectors
#
# Most similar pages
# result = word_vectors.similar_by_word("cat")
# print("{}: {:.4f}".format(*result[0]))
#
# Extracting relationships:
# result = word_vectors.most_similar(positive=['woman', 'king'], negative=['man'])
# print("{}: {:.4f}".format(*result[0]))

result = absKeyedVec.similar_by_word("en/Dog")
print("{}: {:.4f}".format(*result[0]))
print("{}: {:.4f}".format(*result[1]))
print("{}: {:.4f}".format(*result[2]))

result = absKeyedVec.similar_by_word("en/Cat")
print("{}: {:.4f}".format(*result[0]))
print("{}: {:.4f}".format(*result[1]))
print("{}: {:.4f}".format(*result[2]))

result = absKeyedVec.most_similar(
    positive=["en/Donald_Trump", "en/United_States"],
    negative=["en/Denmark"]
)
print("{}: {:.4f}".format(*result[0]))
print("{}: {:.4f}".format(*result[1]))
print("{}: {:.4f}".format(*result[2]))


result = absKeyedVec.most_similar(
    positive=["en/Donald_Trump", "en/United_States"],
    negative=["en/France"]
)
print("{}: {:.4f}".format(*result[0]))
print("{}: {:.4f}".format(*result[1]))
print("{}: {:.4f}".format(*result[2]))

result = absKeyedVec.most_similar(
    positive=["en/France", "en/Paris"],
    negative=["en/Copenhagen"]
)
print("{}: {:.4f}".format(*result[0]))
print("{}: {:.4f}".format(*result[1]))
print("{}: {:.4f}".format(*result[2]))

result = absKeyedVec.most_similar(
    positive=["en/Mona_Lisa", "en/Leonardo_da_Vinci"],
    negative=["en/Jackson_Pollock"]
)
print("{}: {:.4f}".format(*result[0]))
print("{}: {:.4f}".format(*result[1]))
print("{}: {:.4f}".format(*result[2]))

result = absKeyedVec.most_similar(
    positive=["en/Abbey_Road", "en/The_Beatles"],
    negative=["en/Daft_Punk"]
)
print("{}: {:.4f}".format(*result[0]))
print("{}: {:.4f}".format(*result[1]))
print("{}: {:.4f}".format(*result[2]))
